# %% [markdown]
# ## XOR
#
# Aprendizaje Automático
#
# Especialización en Inteligencia de Datos Aplicada
#
# Facultad de Informática - Universidad Nacional del Comahue

# %% [markdown]
# Importar librerias

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Datos del XOR

# %%
# Datos XOR
X = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [1],
              [1],
              [0]])

# %% [markdown]
# Definir modelo ANN

# %%
# Modelo ANN
model = Sequential([
    Dense(2, activation='tanh'),  # capa oculta con 2 neuronas
    Dense(1, activation='sigmoid')             # salida binaria
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Entrenamiento de la red

# %%
# Entrenamiento
model.fit(X, y, epochs=1000, verbose=0)
#model.fit(X, y, epochs=5000, verbose=0)

# %% [markdown]
# Predicciones

# %%
# Predicciones
preds = model.predict(X)
print("Predicciones (sin round):")
print(preds)
print("Predicciones (aproximadas):")
print(np.round(preds))

# %% [markdown]
# Performance

# %%
# Matriz de confusión
cm = confusion_matrix(y, np.round(preds))
print("Matriz de confusión:")
print(cm)

# Visualización
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Matriz de confusión - XOR")
plt.show()
